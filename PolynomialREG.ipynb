# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
#checking the relationship between the data 
#for this case we use the r-squared value to compare the rletaionship (0 to 1)
from sklearn.metrics import r2_score
mymodel = np.poly1d(np.polyfit(x, y, 3))

print("R-squared value: ",r2_score(y, mymodel(x)))
# Out:
# R-squared value:  0.9432150416451026

# %%
#drawing the line of polynomial regression
mymodel = np.poly1d(np.polyfit(x, y, 3))#we are fitting a polynomial of degree 3 to the data
myline = np.linspace(1, 22, 100)#we are creating a line from 1 to 22 with 100 points
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.title('Polynomial Regression')
plt.xlabel('Hour')
plt.ylabel('car speed')
plt.show()

# %%
#predicting values 
print("The car that pass at the 17th hour had a speed of: ", mymodel(17))
# Out:
# The car that pass at the 17th hour had a speed of:  88.87331269698001

# %%
#case when it is a bad fit 

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

my_model = np.poly1d(np.polyfit(x,y,3))

print("R-squared value: ",r2_score(y, my_model(x)))
# Out:
# R-squared value:  0.009952707566680652

# %% [markdown]
# - The r-squared value is very low hence the polynomial fit will not be the best option

# %%
#trying to draw
my_line = np.linspace(2,95,100)

plt.scatter(x, y)
plt.plot(my_line, my_model(my_line))
plt.show()
